# %%
#importar pandas
import pandas as pd


#leer datos 
file_path="./data.csv"
data= pd.read_csv(file_path)
data.head()
# Out:
#                title   type                     genres  releaseYear  \
# 0       Forrest Gump  movie             Drama, Romance       1994.0
# 1  The Fifth Element  movie  Action, Adventure, Sci-Fi       1997.0
# 2  Kill Bill: Vol. 1  movie    Action, Crime, Thriller       2003.0
# 3            Jarhead  movie      Biography, Drama, War       2005.0
# 4         Unforgiven  movie             Drama, Western       1992.0
#
#       imdbId  imdbAverageRating  imdbNumVotes  \
# 0  tt0109830                8.8     2315661.0
# 1  tt0119116                7.6      516953.0
# 2  tt0266697                8.2     1221506.0
# 3  tt0418763                7.0      211503.0
# 4  tt0105695                8.2      443687.0
#
#                                   availableCountries
# 0                                                 MX
# 1                                         AT, CH, DE
# 2  AE, AL, AO, AT, AU, AZ, BG, BH, BY, CA, CI, CM...
# 3  AD, AE, AG, AL, AO, AR, AT, AZ, BA, BB, BG, BH...
# ...

# %%
# Determinar valores únicos
generos_unicos = data["genres"].unique()
print("Generos únicos:", generos_unicos)
# Out:
# Generos únicos: ['Drama, Romance' 'Action, Adventure, Sci-Fi' 'Action, Crime, Thriller'
#  'Biography, Drama, War' 'Drama, Western' 'Drama, Romance, Sci-Fi'
#  'Drama, Thriller' 'Action, Crime, Drama' 'Adventure, Sci-Fi'
#  'Drama, Mystery, Romance' 'Drama, Music' 'Crime, Drama, Thriller'
#  'Drama, Sport' 'Crime, Drama' 'Comedy, Sci-Fi' 'Mystery, Thriller'
#  'Action, Adventure, Drama' 'Adventure, Animation, Sci-Fi'
#  'Action, Adventure' 'Drama, Music, Romance' 'Action, Comedy, Crime'
#  'Comedy, Drama, Romance' 'Comedy, Crime' 'Adventure, Comedy, Family'
#  'Action, Adventure, Animation' 'Adventure, Animation, Family'
#  'Comedy, Crime, Drama' 'Comedy, Drama, Fantasy'
#  'Action, Animation, Drama' 'Comedy, Drama' 'Crime, Thriller'
#  'Horror, Mystery, Thriller' 'Drama, Mystery, Thriller' 'Comedy, Romance'
#  'Adventure, Drama, Thriller' 'Horror, Mystery' 'Adventure, Comedy, Drama'
#  'Drama' 'Action, Sci-Fi' 'Crime, Drama, Mystery' 'Action, Crime, Fantasy'
# ...

# %%
# Explorar el DataFrame
print("\nInformación del DataFrame:")
print(data.info())
# Out:
# Información del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20106 entries, 0 to 20105
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               19612 non-null  object
#  1   type                20106 non-null  object
#  2   genres              19856 non-null  object
#  3   releaseYear         20092 non-null  float64
#  4   imdbId              18848 non-null  object
#  5   imdbAverageRating   18712 non-null  float64
#  6   imdbNumVotes        18712 non-null  float64
#  7   availableCountries  20106 non-null  object
# dtypes: float64(3), object(5)
# memory usage: 1.2+ MB
# None

# %%
# Mostrar los primeros y últimos registros
print("\nPrimeros registros:")
print(data.head(5))

# %%
print("\nÚltimos registros:")
print(data.tail(5))
# Out:
# Últimos registros:
#                                       title type              genres  \
# 20101                                   NaN   tv      Drama, Mystery
# 20102                                   NaN   tv                 NaN
# 20103                                   NaN   tv                 NaN
# 20104                                   NaN   tv                 NaN
# 20105  The Evolution of Black British Music   tv  Documentary, Music
#
#        releaseYear      imdbId  imdbAverageRating  imdbNumVotes  \
# 20101          NaN         NaN                NaN           NaN
# 20102       2024.0         NaN                NaN           NaN
# 20103       2024.0         NaN                NaN           NaN
# 20104          NaN         NaN                NaN           NaN
# 20105       2022.0  tt27912029                7.2          17.0
#
#                                       availableCountries
# 20101  AD, AE, AG, AL, AO, AR, AT, AU, AZ, BA, BB, BE...
# ...
